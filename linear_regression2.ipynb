# %% [markdown]
# <a href="https://colab.research.google.com/github/sunand-kumar/new/blob/master/linear_regression2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Sunith/Documents/IceCreamData.csv')
df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
df.tail()
# Out:
#      Temperature     Revenue
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
x = df.iloc[:,0:1].values
y = df.iloc[:,1].values

# %%
x.shape
# Out:
# (500, 1)

# %%
x
# Out:
# array([[24.56688442],
#        [26.00519115],
#        [27.79055388],
#        [20.59533505],
#        [11.50349764],
#        [14.35251388],
#        [13.70777988],
#        [30.83398474],
#        [ 0.97686999],
#        [31.66946458],
#        [11.45525338],
#        [ 3.66466958],
#        [18.81182403],
#        [13.62450892],
#        [39.53990899],
#        [18.48314099],
#        [25.93537514],
#        [42.51528041],
#        [29.58948056],
#        [21.77594799],
#        [25.45783637],
#        [15.21456942],
#        [22.61931574],
#        [16.25872074],
#        [23.88172478],
#        [18.97830025],
#        [15.6614643 ],
#        [29.18504465],
#        [19.02461092],
#        [35.12015142],
#        [24.18393726],
#        [15.23119012],
#        [ 8.79095281],
#        [18.23322784],
#        [35.62892497],
#        [37.05754246],
#        [22.28455032],
#        [17.51707397],
#        [31.7379196 ],
#        [17.04973761],
#        [23.0034888 ],
# ...

# %%
y.shape
# Out:
# (500,)

# %%
y
# Out:
# array([ 534.7990284 ,  625.1901215 ,  660.6322888 ,  487.7069603 ,
#         316.2401944 ,  367.9407438 ,  308.8945179 ,  696.7166402 ,
#          55.39033824,  737.8008241 ,  325.9684084 ,   71.16015301,
#         467.4467066 ,  289.5409341 ,  905.4776043 ,  469.9090332 ,
#         648.2099977 ,  921.508275  ,  649.5611747 ,  534.6228653 ,
#         612.1539491 ,  353.3256334 ,  524.2361154 ,  374.231135  ,
#         523.1245467 ,  473.6043349 ,  402.4553204 ,  679.3177906 ,
#         517.5340283 ,  809.6720534 ,  528.3804165 ,  356.0980075 ,
#         237.7639106 ,  418.1372788 ,  809.4634112 ,  870.7659159 ,
#         550.2785159 ,  405.6614459 ,  740.9356848 ,  501.7329901 ,
#         539.6880057 ,  242.2362083 ,  421.621505  ,  358.0028493 ,
#         467.631063  ,  396.9356482 ,  500.9250645 ,  651.8615363 ,
#         451.4507843 ,  697.8339862 ,  190.7109408 ,  621.1897304 ,
#         666.1368355 ,  628.4532107 ,  219.3039932 ,  623.5988607 ,
# ...

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 2)

# %%
x_train.shape
# Out:
# (375, 1)

# %%
x_test.shape
# Out:
# (125, 1)

# %%
y_train.shape
# Out:
# (375,)

# %%
y_test.shape
# Out:
# (125,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(47.53129862898936)

# %%
model.coef_
# Out:
# array([21.34996289])

# %%
model.score(x_train, y_train)
# Out:
# 0.9813405856669014

# %%
model.score(x_test, y_test)
# Out:
# 0.973460967221876

# %%
predictions = model.predict(x_test)

# %%
pd.DataFrame([x_test.reshape(-1), predictions.T])
# Out:
#           0           1           2           3           4           5    \
# 0   32.297331   28.464933   31.030333   25.056281   21.540459   20.563015
# 1  737.078123  655.256561  710.027752  582.481964  507.419300  486.550902
#
#           6           7           8           9    ...         115        116  \
# 0   26.005191   15.916678   35.094796   25.725470  ...   26.250746   0.267028
# 1  602.741165  387.351779  796.803881  596.769133  ...  607.983749  53.232330
#
#           117         118         119         120         121         122  \
# 0   24.528853   17.690032   24.113597   27.572960   13.301796   19.024611
# 1  571.221394  425.212817  562.355691  636.212982  331.524157  453.706036
#
#           123         124
# 0   24.778199    8.991760
# 1  576.544918  239.505043
#
# [2 rows x 125 columns]

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train,model.predict(x_train), color= 'black')
plt.title("training data")
plt.xlabel("temperature")
plt.ylabel("ice cream sales")
plt.show()

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_test,model.predict(x_test), color= 'black')
plt.title("training data")
plt.xlabel("temperature")
plt.ylabel("ice cream sales")
plt.show()
