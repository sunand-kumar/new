# %%
#zero shot
prompt= """

i have 15 internal demons ... all but 8 dies.. how many demons left?
"""

# %%
from groq import Groq

client = Groq(
    api_key='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',
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": prompt,
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Let's work through that. You started with 15 internal demons, and all but 8 died. "All but 8" means that 8 demons survived.
#
# So, to find out how many demons are left, we can subtract the number of demons that died from the original total. However, since we're given that "all but 8" died, we can directly say that 8 demons are left.
#
# The math would be: 15 (original demons) - (15 - 8) (demons that died) = 8
#
# Therefore, you have 8 internal demons left.
